# %% [markdown]
# # Horovod を使った分散学習
# Horovod は MPI を使った分散学習のためのフレームワークです。より詳細な情報は [Horovod README](https://github.com/uber/horovod) をご確認下さい。
#
# Amazon SageMaker では Horovod の活用もスクリプトを少し変更するだけで可能です。

# %% [markdown]
# ## Horovod による分散学習を行う学習スクリプトの作成
#
# #### **オリジナルの学習スクリプトである`training_script/cifar10_keras_sm.py`をコピーした上で、`training_script/cifar10_keras_dist.py.`として保存して下さい。新しいファイルを書き換え用のファイルとして使います。**
#
#
# の中において、
#
# #### ① Horovod の設定
#
# Horovod を使用するように `main()` 関数の中に 下記を追加します。
#
#
#
# ```python
#     import horovod.keras as hvd
#     hvd.init()
#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth = True
#     config.gpu_options.visible_device_list = str(hvd.local_rank())
#     K.set_session(tf.Session(config=config))
# ```
#
# #### ② Callbacks の設定
#
# Horovod へ対応するために `main()` 関数の中に callbacks を追加します。
#
# ```python
#     callbacks.append(hvd.callbacks.BroadcastGlobalVariablesCallback(0))
#     callbacks.append(hvd.callbacks.MetricAverageCallback())
#     callbacks.append(hvd.callbacks.LearningRateWarmupCallback(warmup_epochs=5, verbose=1))
# ```
#
# また、checkpoint と tensorboard の callback がシングルプロセスのログだけ送信するように変更します。
#
# ```python
#     if hvd.rank() == 0:
#         callbacks.append(ModelCheckpoint(args.output_dir + '/checkpoint-{epoch}.h5'))
#         callbacks.append(TensorBoard(log_dir=args.model_output_dir,update_freq='epoch'))
# ```
#
# #### ③ Horovod に対応した Optimizer の設定変更
# Horovod へ対応するために keras_model_fn へ `hvd` 引数を追加します。
#
# ```python
# #  hvd を追加します。
# def keras_model_fn(learning_rate, weight_decay, optimizer, momentum, hvd):
# ```
# また、model インスタンスを作成する際に、`hvd` を引数に渡します。
# ```python
# model = keras_model_fn(args.learning_rate, args.weight_decay, args.optimizer, args.momentum, hvd)
# ```
#
# その、`keras_model_fn()` 関数の中において`size=1` を `size=hvd.size()`　へ変更。
#
# さらに、
# ```python
#  model.compile(loss='categorical_crossentropy',
#                   optimizer=opt,
#                   metrics=['accuracy'])
# ```
# の直前に
#
# ```python
# opt = hvd.DistributedOptimizer(opt)
# ```
# を追加。

# %% [markdown]
# ## 分散学習の実行
# To start a distributed training job with Horovod, configure the job distribution:
# ```python
# distributions = {'mpi': {
#                     'enabled': True,
#                     'processes_per_host': # Number of Horovod processes per host
#                         }
#                 }
# ```
#
# Run the same job using 2 ml.p3.2xlarge instances (processes_per_host:1).
# add the distributions configuration

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()


dataset_location = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-cifar10')
display(dataset_location)
# Out:
# 's3://sagemaker-us-east-1-815969174475/data/DEMO-cifar10'

# %%
from sagemaker.tensorflow import TensorFlow

distributions = {'mpi': {
                    'enabled': True,
                    'processes_per_host': 1}
                }

# Change base_job_name to 'cifar10-dist' for console visibility
estimator = TensorFlow(base_job_name='cifar10',
                       entry_point='cifar10_keras_sm_sample3.py',
                       source_dir='training_script',
                       role=role,
                       framework_version='1.12.0',
                       py_version='py3',
                       hyperparameters={'epochs' : 10},
                       train_instance_count=2,
                       train_instance_type='ml.p3.2xlarge',
                       distributions=distributions
                      )

# %%
estimator.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# 2019-10-01 02:54:01 Starting - Starting the training job...
# 2019-10-01 02:54:03 Starting - Launching requested ML instances......
# 2019-10-01 02:55:07 Starting - Preparing the instances for training......
# 2019-10-01 02:56:19 Downloading - Downloading input data...
# 2019-10-01 02:56:56 Training - Training image download completed. Training in progress..2019-10-01 02:56:54,159 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-10-01 02:56:57,471 sagemaker-containers INFO     Starting MPI run as worker node.
# 2019-10-01 02:56:57,472 sagemaker-containers INFO     Waiting for MPI Master to create SSH daemon.
# 2019-10-01 02:56:57,473 sagemaker-containers INFO     Cannot connect to host algo-1
# 2019-10-01 02:56:57,473 sagemaker-containers INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.2.224.32
# 2019-10-01 02:56:58,474 sagemaker-containers INFO     Cannot connect to host algo-1
# 2019-10-01 02:56:58,474 sagemaker-containers INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.2.224.32
# 2019-10-01 02:56:59,483 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python3.6/dist-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/dist-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/dist-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# 2019-10-01 02:56:59,640 paramiko.transport INFO     Authentication (publickey) successful!
# 2019-10-01 02:56:59,640 sagemaker-containers INFO     Can connect to host algo-1
# 2019-10-01 02:56:59,642 sagemaker-containers INFO     MPI Master online, creating SSH daemon.
# 2019-10-01 02:56:59,649 sagemaker-containers INFO     Waiting for MPI process to finish.
# 2019-10-01 02:56:58,896 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-10-01 02:56:59,170 sagemaker-containers INFO     Starting MPI run as worker node.
# 2019-10-01 02:56:59,171 sagemaker-containers INFO     Creating SSH daemon.
# 2019-10-01 02:56:59,176 sagemaker-containers INFO     Waiting for MPI workers to establish their SSH connections
# 2019-10-01 02:56:59,178 sagemaker-containers INFO     Cannot connect to host algo-2
# 2019-10-01 02:56:59,178 sagemaker-containers INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.2.231.226
# 2019-10-01 02:57:00,185 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python3.6/dist-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/dist-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/dist-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# 2019-10-01 02:57:00,336 paramiko.transport INFO     Authentication (publickey) successful!
# 2019-10-01 02:57:00,336 sagemaker-containers INFO     Can connect to host algo-2
# 2019-10-01 02:57:00,337 sagemaker-containers INFO     Worker algo-2 available for communication
# 2019-10-01 02:57:00,337 sagemaker-containers INFO     Env Hosts: ['algo-1', 'algo-2'] Hosts: ['algo-1', 'algo-2'] process_per_hosts: 1 num_processes: 2
# 2019-10-01 02:57:00,341 sagemaker-containers INFO     Network interface name: eth0
# 2019-10-01 02:57:00,370 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_num_of_processes_per_host": 1,
#         "sagemaker_mpi_custom_mpi_options": "",
#         "sagemaker_mpi_enabled": true
#     },
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "/opt/ml/model",
#         "epochs": 10
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cifar10-2019-10-01-02-54-00-979",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-815969174475/cifar10-2019-10-01-02-54-00-979/source/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_sm_sample3",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_sm_sample3.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":10,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=cifar10_keras_sm_sample3.py
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":1}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_sm_sample3
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-815969174475/cifar10-2019-10-01-02-54-00-979/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":1},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"epochs":10,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cifar10-2019-10-01-02-54-00-979","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-815969174475/cifar10-2019-10-01-02-54-00-979/source/sourcedir.tar.gz","module_name":"cifar10_keras_sm_sample3","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_sm_sample3.py"}
# SM_USER_ARGS=["--epochs","10","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=10
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1,algo-2 -np 2 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to socket -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.6/dist-packages/gethostname.cpython-36m-x86_64-linux-gnu.so -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_EVAL -x SM_CHANNEL_VALIDATION -x SM_CHANNEL_TRAIN -x SM_HP_MODEL_DIR -x SM_HP_EPOCHS -x PYTHONPATH /usr/bin/python -m mpi4py cifar10_keras_sm_sample3.py --epochs 10 --model_dir /opt/ml/model
#
#
# Warning: Permanently added 'algo-2,10.2.231.226' (ECDSA) to the list of known hosts.#015
# --------------------------------------------------------------------------
# WARNING: a request was made to bind a process. While the system
# supports binding the process itself, at least one node does NOT
# support binding memory to the process location.
#  Data for JOB [37999,1] offset 0 Total slots allocated 2
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-2-224-32#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [37999,1] App: 0 Process rank: 0 Bound: UNBOUND
#
#  Data for node: algo-2#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [37999,1] App: 0 Process rank: 1 Bound: N/A
#
#  =============================================================
#
#   Node:  ip-10-2-224-32
#
# Open MPI uses the "hwloc" library to perform process and memory
# binding. This error message means that hwloc has indicated that
# processor binding support is not available on this machine.
#
# On OS X, processor and memory binding is not available at all (i.e.,
# the OS does not expose this functionality).
#
# On Linux, lack of the functionality can mean that you are on a
# platform where processor and memory affinity is not supported in Linux
# itself, or that hwloc was built without NUMA and/or processor affinity
# support. When building hwloc (which, depending on your Open MPI
# installation, may be embedded in Open MPI itself), it is important to
# have the libnuma header and library files available. Different linux
# distributions package these files under different names; look for
# packages with the word "numa" in them. You may also need a developer
# version of the package (e.g., with "dev" or "devel" in the name) to
# obtain the relevant header files.
#
# If you are getting this message on a non-OS X, non-Linux platform,
# then hwloc does not support processor / memory affinity on this
# platform. If the OS/platform does actually support processor / memory
# affinity, then you should contact the hwloc maintainers:
# https://github.com/open-mpi/hwloc.
#
# This is a warning only; your job will continue, though performance may
# be degraded.
# --------------------------------------------------------------------------
# [1,0]<stderr>:Using TensorFlow backend.
# [1,1]<stderr>:2019-10-01 02:57:03.112640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-01 02:57:03.113576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# [1,1]<stderr>:name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# [1,1]<stderr>:pciBusID: 0000:00:1e.0
# [1,1]<stderr>:totalMemory: 15.75GiB freeMemory: 15.44GiB
# [1,1]<stderr>:2019-10-01 02:57:03.113604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# [1,1]<stderr>:2019-10-01 02:57:04.193516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,1]<stderr>:2019-10-01 02:57:04.193556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# [1,1]<stderr>:2019-10-01 02:57:04.193565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# [1,1]<stderr>:2019-10-01 02:57:04.193696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14940 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# [1,1]<stdout>:Namespace(batch_size=128, epochs=10, eval='/opt/ml/input/data/eval', learning_rate=0.001, model_dir='/opt/ml/model', model_output_dir='/opt/ml/model', momentum=0.9, optimizer='adam', train='/opt/ml/input/data/train', validation='/opt/ml/input/data/validation', weight_decay=0.0002)
# [1,0]<stdout>:Namespace(batch_size=128, epochs=10, eval='/opt/ml/input/data/eval', learning_rate=0.001, model_dir='/opt/ml/model', model_output_dir='/opt/ml/model', momentum=0.9, optimizer='adam', train='/opt/ml/input/data/train', validation='/opt/ml/input/data/validation', weight_decay=0.0002)
# [1,1]<stderr>:2019-10-01 02:57:04.425090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# [1,1]<stderr>:2019-10-01 02:57:04.530468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,1]<stderr>:2019-10-01 02:57:04.530514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# [1,1]<stderr>:2019-10-01 02:57:04.530523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# [1,1]<stderr>:2019-10-01 02:57:04.530620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14940 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# [1,1]<stderr>:Using TensorFlow backend.
# [1,1]<stderr>:INFO:root:getting data
# [1,0]<stderr>:INFO:root:getting data
# [1,1]<stderr>:INFO:root:configuring model
# [1,0]<stderr>:INFO:root:configuring model
# [1,1]<stderr>:INFO:root:Starting training
# [1,0]<stderr>:INFO:root:Starting training
# [ip-10-2-224-32.ec2.internal:00046] 1 more process has sent help message help-orte-rmaps-base.txt / rmaps:membind-not-supported
# [ip-10-2-224-32.ec2.internal:00046] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [1,1]<stdout>:Train on 128 samples, validate on 128 samples
# [1,0]<stdout>:Train on 128 samples, validate on 128 samples
# [1,1]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:algo-1:52:94 [0] misc/ibvwrap.cu:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO Using internal Network Socket
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO NET : Using interface eth0:10.2.224.32<0>
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO NET/Socket : 1 interfaces found
# [1,0]<stdout>:NCCL version 2.3.5+cuda9.0
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO rank 0 nranks 2
# [1,1]<stdout>:
# [1,1]<stdout>:algo-2:59:101 [0] misc/ibvwrap.cu:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,1]<stdout>:algo-2:59:101 [0] NCCL INFO Using internal Network Socket
# [1,1]<stdout>:algo-2:59:101 [0] NCCL INFO rank 1 nranks 2
# [1,1]<stdout>:algo-2:59:101 [0] NCCL INFO comm 0x7fd550329a60 rank 1 nranks 2
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO comm 0x7f49c42dfff0 rank 0 nranks 2
# [1,1]<stdout>:algo-2:59:101 [0] NCCL INFO NET : Using interface eth0:10.2.231.226<0>
# [1,1]<stdout>:algo-2:59:101 [0] NCCL INFO NET/Socket : 1 interfaces found
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO CUDA Dev 0, IP Interfaces : eth0(PHB)
# [1,1]<stdout>:algo-2:59:101 [0] NCCL INFO CUDA Dev 0, IP Interfaces : eth0(PHB)
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO Duplicating rings to 4 per user request.
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO Using 256 threads
# [1,1]<stdout>:algo-2:59:101 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO Min Comp Cap 7
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO Ring 00 :    0   1
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INFO [1,0]<stdout>:Ring 01 :    0   1
# [1,0]<stdout>:algo-1:52:94 [0] NCCL INF
1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:183/312 [================>.............] - ETA: 4s - loss: 0.6297 - acc: 0.7845[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:184/312 [================>.............] - ETA: 4s - loss: 0.6271 - acc: 0.7843[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:185/312 [================>.............] - ETA: 4s - loss: 0.6300 - acc: 0.7844[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:186/312 [================>.............] - ETA: 4s - loss: 0.6281 - acc: 0.7839[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:186/312 [================>.............] - ETA: 4s - loss: 0.6299 - acc: 0.7846[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:189/312 [=================>............] - ETA: 4s - lo ...
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:300/312 [===========================>..] - ETA: 0s - loss: 0.6315 - acc: 0.7828[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:300/312 [===========================>..] - ETA: 0s - loss: 0.6273 - acc: 0.7858[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:301/312 [===========================>..] - ETA: 0s - loss: 0.6313 - acc: 0.7828[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:303/312 [============================>.] - ETA: 0s - loss: 0.6265 - acc: 0.7860[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:304/312 [============================>.] - ETA: 0s - loss: 0.6314 - acc: 0.7828[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:305/312 [============================>.] - ETA: 0s - loss: 0.6271 - acc: 0.7858[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:306/312 [============================>.] - ETA: 0s - loss: 0.6313 - acc: 0.7827[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:308/312 [============================>.] - ETA: 0s - loss: 0.6276 - acc: 0.7855[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:309/312 [============================>.] - ETA: 0s - loss: 0.6310 - acc: 0.7830[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01 ...
# [1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:312/312 [==============================] - 11s 35ms/step - loss: 0.6273 - acc: 0.7855 - val_loss: 0.6173 - val_acc: 0.7917
# [1,1]<stderr>:INFO:root:Test loss:0.6382036667603713
# [1,1]<stderr>:INFO:root:Test accuracy:0.7826522435897436
# [1,1]<stderr>:INFO:tensorflow:No assets to save.
# [1,1]<stderr>:INFO:tensorflow:No assets to save.
# [1,1]<stderr>:INFO:tensorflow:No assets to write.
# [1,1]<stderr>:INFO:tensorflow:No assets to write.
# [1,0]<stderr>:INFO:root:Test loss:0.6397220882085654
# [1,0]<stderr>:INFO:root:Test accuracy:0.7842548076923077
# [1,0]<stderr>:INFO:tensorflow:No assets to save.
# [1,0]<stderr>:INFO:tensorflow:No assets to save.
# [1,0]<stderr>:INFO:tensorflow:No assets to write.
# [1,0]<stderr>:INFO:tensorflow:No assets to write.
# [1,1]<stderr>:INFO:tensorflow:SavedModel written to: /opt/ml/model/1/saved_model.pb
# [1,1]<stderr>:INFO:tensorflow:SavedModel written to: /opt/ml/model/1/saved_model.pb
# [1,1]<stderr>:INFO:root:Model successfully saved at: /opt/ml/model
# [1,0]<stderr>:INFO:tensorflow:SavedModel written to: /opt/ml/model/1/saved_model.pb
# [1,0]<stderr>:INFO:tensorflow:SavedModel written to: /opt/ml/model/1/saved_model.pb
# [1,0]<stderr>:INFO:root:Model successfully saved at: /opt/ml/model
# 2019-10-01 02:59:29,796 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2019-10-01 03:00:04 Uploading - Uploading generated training model2019-10-01 02:59:59,838 sagemaker-containers INFO     MPI process finished.
# 2019-10-01 02:59:59,838 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2019-10-01 03:00:25 Completed - Training job completed
# Training seconds: 492
# Billable seconds: 492

# %% [markdown]
# **Good job!**
# You can now use SageMaker training jobs for distributed jobs.
# Before continuing to the next notebook, look at the distribution job metrics from CloudWatch and TensorBoard.
# You can use TensorBoard to compare between the different jobs that you ran.
# Run TensorBoard with
# `--logdir dist:dist_model_dir,pipe:pipe_model_dir,file:normal_job_model_dir`
